# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Using cached emoji-1.4.2.tar.gz (184 kB)
# Using legacy 'setup.py install' for emoji, since package 'wheel' is not installed.
# Installing collected packages: emoji
#     Running setup.py install for emoji: started
#     Running setup.py install for emoji: finished with status 'done'
# Successfully installed emoji-1.4.2
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\chathurya\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install mysql
# Out:
# Collecting mysql
#   Downloading mysql-0.0.3-py3-none-any.whl (1.2 kB)
# Collecting mysqlclient
#   Downloading mysqlclient-2.0.3-cp39-cp39-win_amd64.whl (179 kB)
# Installing collected packages: mysqlclient, mysql
# Successfully installed mysql-0.0.3 mysqlclient-2.0.3
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\chathurya\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.0.2
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\chathurya\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\chathurya\appdata\local\programs\python\python39\lib\site-packages (8.0.26)
# Collecting protobuf>=3.0.0
#   Downloading protobuf-3.17.3-cp39-cp39-win_amd64.whl (909 kB)
# Collecting six>=1.9
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, protobuf
# Successfully installed protobuf-3.17.3 six-1.16.0
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\chathurya\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import re
import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk
#nltk.download('all')
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from collections import Counter
from nltk.stem import WordNetLemmatizer
from functools import partial
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.metrics import confusion_matrix , classification_report
# %matplotlib inline

from wordcloud import WordCloud

#sentiment calculation
import emoji
from nltk.corpus import sentiwordnet as swn

#Weighted Additive
import math

# mysql
import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-12ed63afff7c> in <module>
#      27
#      28 # mysql
# ---> 29 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt

# %%
# Replaces url
def replaceURL(text):
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','url',text)
#    text = re.sub(r'#([^\s]+)', r'\1', text)
    return text

# %%
# Replace slangs

# Creates a dictionary with slangs and their equivalents and replaces them
with open('slang.txt') as file:
    slang_map = dict(map(str.strip, line.partition('\t')[::2])
    for line in file if line.strip())

slang_words = sorted(slang_map, key=len, reverse=True) # longest first for regex
regex = re.compile(r"\b({})\b".format("|".join(map(re.escape, slang_words))))
replaceSlang = partial(regex.sub, lambda m: slang_map[m.group(1)])

# %%
# separate the hash tags

# function to collect hashtags
def hashtag_extract(x):
    words = x.split()
    hashtags = []
    # Loop over the words in the tweet
    for i in words:
        ht = re.findall(r"#(\w+)", i)
        hashtags.append(ht)
    hashtags = sum(hashtags,[])
    return hashtags

# %%
#Remove hashtag from tidy tweet
def remove_hashtags(sentence):
    return ' '.join(re.sub("#(\w+)"," ",sentence).split())

# %%
#Hashtag decompositon(CamelCase)
def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return ' '.join([m.group(0) for m in matches])

# %%
def extract_emojis(s):
    return ' '.join(c for c in s if c in emoji.UNICODE_EMOJI['en'])

# %%
def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

# %%
emojiSentiment = pd.read_csv('Emoji_Sentiment_Data.csv')
emojiSentiment['emoji value'] = emojiSentiment['emoji value'].apply(lambda x : chr(int(x,16)))

# %%
#Assign sentiment value to the emoji
all_emojis = list(emojiSentiment['emoji value'])

def getIndexOfEmoji(emoji):
    for i in range(len(all_emojis)):
        if(emoji == all_emojis[i]):
            return i
    return 1
  #return -1

def getEmojiSentimentScore(emoji):
    index = getIndexOfEmoji(emoji)
    return emojiSentiment.loc[index, 'sentiment score']

def getSentimentScore(emojis):
    if(len(emojis) == 0):
        return ""
    emojis = emojis.split(" ")
    sum = 0
    count = 0
    for emoji in emojis:
        sum += getEmojiSentimentScore(emoji)
        count = count + 1
    return sum/count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9dc513564dde> in <module>()
#       1 #Assign sentiment value to the emoji
# ----> 2 all_emojis = list(emojiSentiment['emoji value'])
#       3
#       4 def getIndexOfEmoji(emoji):
#       5     for i in range(len(all_emojis)):
#
# NameError: name 'emojiSentiment' is not defined

# %%
# Removing RT
def removeRTInFrontOfWord(text):
    text = re.sub(r'\brt\b', '', text).strip()
    return text

# %%
def runFun(ls, func):
    newls = []
    for i in ls:
        newls.append(func(i))
    return newls

# %%
# Elongated
def replaceElongated(word):
    repeat_regexp = re.compile(r'(\w*)(\w)\2(\w*)')
    repl = r'\1\2\3'
    if wordnet.synsets(word):
        return word
    repl_word = repeat_regexp.sub(repl, word)
    if repl_word != word:      
        return replaceElongated(repl_word)
    else:       
        return repl_word

# %%
# Spell Correction http://norvig.com/spell-correct.html """
def words(text): return re.findall(r'\w+', text.lower())

# All edits that are one edit away from `word`.
def edits1(word):
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

#  All edits that are two edits away from `word`.
def edits2(word): 
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

WORDS = Counter(words(open('corporaForSpellCorrection.txt').read()))

# Generate possible spelling corrections for word
def candidates(word): 
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

# The subset of `words` that appear in the dictionary of WORDS
def known(words): 
    return set(w for w in words if w in WORDS)

# P robability of `word`.
def P(word, N=sum(WORDS.values())): 
    return WORDS[word] / N

# Most probable spelling correction for word. 
def spellCorrection(word): 
    return max(candidates(word), key=P)

# %%
# removing stop words
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
#stopwords.words('english')
stoplist = stopwords.words('english')
my_stopwords = "multiexclamation multiquestion multistop url atuser st rd nd th am pm" # my extra stopwords
stoplist = stoplist + my_stopwords.split()

def removeStopWords(ls):
    return list(filter(lambda w: w not in stoplist, ls))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
wnl = nltk.WordNetLemmatizer()

# calucalting sentiScore- tidy tweet
def calculateSentScore(taggedsent):
    score_list=[]
    for idx2,t in enumerate(taggedsent):
        newtag=''
        lemmatized=wnl.lemmatize(t[0])
        if t[1].startswith('NN'):
            newtag='n'
        elif t[1].startswith('JJ'):
            newtag='a'
        elif t[1].startswith('V'):
            newtag='v'
        elif t[1].startswith('R'):
            newtag='r'
        else:
            newtag=''       
        if(newtag!=''):    
            synsets = list(swn.senti_synsets(lemmatized, newtag))
            #Getting average of all possible sentiment        
            score=0
            if(len(synsets)>0):
                for syn in synsets:
                    score+=syn.pos_score()-syn.neg_score()
                score_list.append(score/len(synsets))
    if(len(score_list) != 0):
        return (sum([word_score for word_score in score_list])/len(score_list))

# %%
# calucalting sentiScore-hashtags
def calculateHashtagsSentiScore(hashtags):
    taggedlist=[]
    for hashtag in hashtags: 
        hashtagWords =  hashtag.split()
        taggedlist.append(nltk.pos_tag(hashtagWords))
    score_list=[]
    for idx,taggedsent in enumerate(taggedlist):
        score_list.append([])
        for idx2,t in enumerate(taggedsent):
            newtag=''
            lemmatized=wnl.lemmatize(t[0])
            if t[1].startswith('NN'):
                newtag='n'
            elif t[1].startswith('JJ'):
                newtag='a'
            elif t[1].startswith('V'):
                newtag='v'
            elif t[1].startswith('R'):
                newtag='r'
            else:
                newtag=''       
            if(newtag!=''):    
                synsets = list(swn.senti_synsets(lemmatized, newtag))
                #Getting average of all possible sentiments        
                score=0
                if(len(synsets)>0):
                    for syn in synsets:
                        score+=syn.pos_score()-syn.neg_score()
                    score_list[idx].append(score/len(synsets))
    sentence_sentiment=[]
    for score_sent in score_list:
        if(len(score_sent) != 0):
            sentence_sentiment.append(sum([word_score for word_score in score_sent])/len(score_sent))
    
    if(len(sentence_sentiment) > 0):
        return sum(sentence_sentiment)/len(sentence_sentiment)
    else:
        return ''

# %%
def sentiment(final_score):
    if final_score is None:
        return np.nan
    elif final_score > 0.0:
        return "positive"
    elif final_score < 0.0:
        return "negative"
    else:
        return "neutral"

# %%
def lexicon_sentiment(tweet):
    ### preprocess ###
    
    # remove twitter handles (@user)
    tidy_tweet = remove_pattern(tweet, "@[\w]*")
    
    # replaces url
    tidy_tweet = replaceURL(tidy_tweet)
    
    # removing short words
    tidy_tweet = ' '.join([w for w in tidy_tweet.split() if len(w)>3])
    
    # replace slang words
    
    # separate the hash tags
    hashtags = hashtag_extract(tidy_tweet)
    
    # remove hashtag from tidy tweet
    tidy_tweet = remove_hashtags(tidy_tweet)                      
    
    # hashtag decompositon(CamelCase)
    hashtags = [camel_case_split(hashtag) for hashtag in hashtags]
    
    # seperate emojis
    emojis = extract_emojis(tidy_tweet)
    
    # remove emoj from tidy tweet
    tidy_tweet = deEmojify(tidy_tweet)
    
    # lowercase
    tidy_tweet = tidy_tweet.lower()
    hashtags = [hashtag.lower() for hashtag in hashtags]
    
    # removing RT
    tidy_tweet = removeRTInFrontOfWord(tidy_tweet)
    
    # remove special characters, numbers, punctuations
    tidy_tweet = tidy_tweet.replace("[^a-zA-Z#]", " ")
    
    # tokenization
    tokenized_tweet = tidy_tweet.split()
    
    # elongated
    tokenized_tweet = runFun(tokenized_tweet, replaceElongated)
    
    # spell correction
    #tokenized_tweet = runFun(tokenized_tweet, spellCorrection)
    
    # removing stop words
    tokenized_tweet = removeStopWords(tokenized_tweet)
    
    # lemmatizer
    lemmatizer = WordNetLemmatizer()
    tokenized_tweet = [lemmatizer.lemmatize(i) for i in tokenized_tweet]
    
    # POS Tagging
    tokenized_tweet_POS = nltk.pos_tag(tokenized_tweet)
    
    # stitch tokens back together
    tidy_tweet = ' '.join(tokenized_tweet)
    
    # get tweet score
    tweet_score = calculateSentScore(tokenized_tweet_POS)
    
    # get hashtag score
    hashtag_score = calculateHashtagsSentiScore(hashtags)
    
    # get emoji score
    emoji_score = getSentimentScore(emojis)
    
    # get score
    tweet_len = len(tokenized_tweet)
    hashtag_len = len(hashtags)
    
    if(emojis != ''):
        emoji_len = len(emojis.split(" "))
    else:
        emoji_len = 0
        
    total_len = tweet_len + hashtag_len + emoji_len
    
    if(total_len == 0):
        return

    tweet_weight = tweet_len/total_len
    hashtag_weight = hashtag_len/total_len
    emoji_weight = emoji_len/total_len

    if(type(tweet_score) != float):
        tweet_score = 0
    if(emoji_score == ''):
        emoji_score = 0
    if(hashtag_score == ''):
        hashtag_score = 0

    return tweet_weight*tweet_score + hashtag_weight*hashtag_score + emoji_weight*emoji_score

# %%
# calculate tweet sentiment and store it in database
mydb = mysql.connector.connect(host="localhost", user="admin1", password="12345", database="testdb")
mycursor = mydb.cursor()

sql = "INSERT INTO tweet_table(tweet, sentiment_intensity) VALUES (%s, %s)"

def tweetToDB(tweet):
    sentiment_intensity =  lexicon_sentiment(tweet)
    if(sentiment_intensity is not None):
        sentiment_intensity = float(sentiment_intensity)                 
    val = (tweet, sentiment_intensity)
    mycursor.execute(sql, val)
    mydb.commit()
    print(mycursor.rowcount, "record inserted.")

# %%
combi = pd.read_csv('test_data.csv', usecols=['tweet'])
tweets = list(combi['tweet'])
tweets
# Out:
# ['So far 24 people infected with the Delta COVID variant in Sri Lanka - Director General of Health Services /â€¦ https://t.co/qKZBdVWf3p',
#  'The highest number of vaccines per day of 232,526 admininistred on July 12.  So far over 4 million first doses of tâ€¦ https://t.co/3hpBOvdJjJ',
#  'Police Media says investigations are continuing and speed-up in connection with sexually abusing the minor girl. Soâ€¦ https://t.co/N4cNsUxQct',
#  'Sri Lanka ðŸ‡±ðŸ‡° introduces Digital Tourism and planning to launch promotions to attract digital tourists to the countrâ€¦ https://t.co/laxAo3XkCL',
#  'TragedyðŸ˜¢\nMother kills her newborn baby and burnt the body immediately after delivery in Kantale area- Police.â€¦ https://t.co/NxlUGaDhHq',
#  'The United States continues to support small businesses in #SriLanka as they work to overcome the economic challengâ€¦ https://t.co/AP6Fn6ADwi',
#  'Drug dealer "Kudu Noni" arrested for transporting Heroin islandwide through a Courier service after packed heroin iâ€¦ https://t.co/UPwal1Gd7L',
#  'Billionaire and Virgin Galactic founder Richard Branson has flown to the edge of space in a great leap towards makiâ€¦ https://t.co/lQxQgUCg7e',
#  'Heavy vehicles advised to avoid Kandy-Kurunegala main road due to collapsed building - Govt Info #LKA #SriLanka',
#  'Coronavirus stats in #SriLanka\nðŸ”µTotal 276,106 infected\nðŸ”µ246,241 recovered \nðŸ”µ3533 deaths\nðŸ”´26,363 active cases\nðŸ”´Dailyâ€¦ https://t.co/nAzAPmBGv2',
#  'RT @CassilingamG: #Jaffna - Vaccination Update - Over 50,000 ppl have been vaccinated under Phase 2 of the program which is progressing smoâ€¦',
#  'Bogala Graphite mine has been closed for two weeks after 35 workers tested positive for COVID - @NewsCenterLkâ€¦ https://t.co/uwCHK3cqxA',
#  '31 more coronavirus related deaths confirmed for July 11th in Sri Lanka - Govt Info #LKA #SriLanka #COVID19SL #COVID19LK',
#  'So far today 920 coronavirus cases report in Sri Lanka #LKA #SriLanka #COVID19SL #COVID19LK',
#  "RT @factcrescendosl: Misleading ðŸš¨\nPolice confirms Kotuwe Podi Hamuduruwo Thero's name is NOT mentioned in 15-year old girl abuse investigatâ€¦",
#  'Update: Chairman of the Chilaw Urban Council arrested over an assault incident, granted bail - Hiru #LKA #SriLanka https://t.co/NDX7yrbyin',
#  'Release Union LeadersâœŠ\nCivil society, students and trade unions are protesting in Colombo against the proposed Koteâ€¦ https://t.co/gAL9yh8scs',
#  'Another consignment of 26,000 doses of Pfizer vaccines received by Sri Lanka this morning #LKA #SriLanka #VaccinationDriveSL',
#  'RT @CassilingamG: Visited the organic fertilizer manufacturing plant in Kallundai, Jaffna. As demand for organic fertilizer has increased iâ€¦',
#  'Sri Lanka Navy seizes about 344 Kg of Kerala Ganja (KG Cannabis) with 3 suspects in Northern waters seas off the Anâ€¦ https://t.co/BJhPDDWe3P',
#  'Police arrested a doctor and later remanded for taking photographs of female doctors while changing clothes -â€¦ https://t.co/BRqksYBCus',
#  '#SriLanka reaches 4 million milestone for Covid-19 vaccinations program ðŸ‘\x8fðŸ‘\x8f\nSo far more than 4 million Sri Lankans hâ€¦ https://t.co/A11s3Q9np2',
#  'Italy ðŸ‡®ðŸ‡¹ won the #EURO2020 !\nPlayer of the Tournament Gianluigi Donnarumma inspiring #Italy to EURO glory! ðŸ§¤\nðŸš« 3 clâ€¦ https://t.co/XnxxJEYC9w',
#  "Several teachers' and principals' unions to withdraw from the online education program for students from today in pâ€¦ https://t.co/XGUDDDnIrG",
#  'Police arrested Chairman of the Chilaw Urban Council over assaulting two persons - @NewsCenterLk https://t.co/eAlCnzYzf5 #LKA #SriLanka',
#  'Health Officials request those who have\nðŸ”ºBreathing difficulties\nðŸ”ºShortness of breath\nto seek immediate treatment frâ€¦ https://t.co/lX0NesIwFe',
#  'Italy ðŸ‡®ðŸ‡¹ #EURO2020 Champions !\nItaly beat England 3-2 in a penalty shootout after 1-1 draw at Wembley.\nCongratulatiâ€¦ https://t.co/wZQ4JBRBMb',
#  '35 more coronavirus related deaths confirmed for July 10th in Sri Lanka - Govt Info #LKA #SriLanka #COVID19SL #COVID19LK',
#  'Police arrested another 2 suspects including a police officer and a former bank manager over the incident of sexualâ€¦ https://t.co/j2GEbHWb3c',
#  'Tragedy!\nðŸŒ³â¤µï¸\x8fðŸŒ´â¤µï¸\x8fðŸ¤•\nMan died after Coconut tree falls on him while he was chopping down a Jackfruit tree.â€¦ https://t.co/LoF0qt4sfY',
#  '2 SriLankan Airlines flights with 2 million doses of Sinopharm vaccines ðŸ’‰from China land ðŸ›¬at BIA, the largest consiâ€¦ https://t.co/GdLFNX7MUy',
#  'Media Minister says they had a discussion with top lawyers over certain media which operate outside legal frameworkâ€¦ https://t.co/vUJJrI8ydZ',
#  'Internationally recognized COVID19 Vaccine Digital Certificate (Smart Digital Vaccine Certificate) was introduced aâ€¦ https://t.co/kqyE7eDKo2',
#  'Argentina ðŸ‡¦ðŸ‡· won #CopaAmerica final ðŸ\x8f†.\nFootball superstar Lionel Messi wins his first trophy with his national teamâ€¦ https://t.co/l7sEZvRt9u',
#  'RT @NewsCenterLk: (watch) "Silence is also a voice: Our stand on dual citizens is not changed" - Minister Wimal Weerawansa. #Lka \nMore Detaâ€¦',
#  'RT @ViranCorea: BASL letter to DG, Health Services &amp; IGP regarding arrest and quarantining of peaceful protesters, stresses inter alia, thaâ€¦',
#  'Muslims in Sri Lanka ðŸ‡±ðŸ‡° will celebrate the Hajj Festival on July 21 as the new moon ðŸŒ™ has NOT been sighted -Colomboâ€¦ https://t.co/CQKCwjTx2W',
#  'Update - so far today 1515 coronavirus cases report in Sri Lanka #LKA',
#  'So far today 919 coronavirus cases report in Sri Lanka #LKA',
#  '33 more covid related deaths confirmed for July 9th in Sri Lanka #LKA #SriLanka #COVID19SL',
#  'Sri Lanka government to borrow two loans amounting to USD 150 million from the Asian Development Bank (ADB) to implâ€¦ https://t.co/xrttJoK3p4',
#  'Hatton - Colombo main road closed from Yatiberiya area due to an earth slip #LKA #weathersl',
#  '7 members of the local company which represent cargo ship MV X-Press Pearl, arrested by police CID &amp; will be produced before court #LKA',
#  'Sri Lanka government has NOT taken any decision to import chemical fertilizer as reported in certain media says Preâ€¦ https://t.co/K7UmjdCy1L',
#  'A thief breaking into a house in Wattala area has died after attacked with a cricket bat ðŸ\x8f\x8f by the owners of the houâ€¦ https://t.co/ldjztStXRq',
#  'Inter-province travel restrictions extended for another 14 days -DG Health Services / Adaderana\n#LKA #SriLanka #TravelRestrictions',
#  'Never underestimate Dengue Feverâ\x9d—\nDengue cases are rising. So far this year 9436 Dengue Fever cases report.\nKeep yoâ€¦ https://t.co/IIykNLjqVI',
#  'Electricity supply disrupted for about 85,000 consumers in Gampaha, Galle, Kurunegala, Kegalle and Puttalam districâ€¦ https://t.co/Hi5Vjyv7lf',
#  'Strong Wind AlertðŸŒªï¸\x8fâ\x9d—ï¸\x8f\nVery strong gusty winds up to 70-80 kmph are likely over western slope of Central hills, Nortâ€¦ https://t.co/sON9xTAwPT',
#  'Flood Alertâ\x9d—ï¸\x8f\nWater levels in Kelani, Kalu, Gin Ganga and Nilwala rivers rising, minor flood situation reports in sâ€¦ https://t.co/QuXj6xeKMo',
#  'So far today total 1537 coronavirus cases report in Sri Lanka. 13,940 PCR tests have done. #LKA #SriLanka #COVID19SL',
#  'Weather Alertâ\x9d—ï¸\x8f\nðŸ”¸Prevailing rainy &amp; windy weather to continue\nðŸ”¸Very heavy rains above 150 mm\nðŸ”¸Strong gusty winds upâ€¦ https://t.co/7hnAmAVaUH',
#  'RT @princeleone: @SriLankaTweet EVERY WOMAN MUST LISTEN TO THIS ðŸ˜\x8d\n\nThe most POWERFUL, HEART TOUCHING, HEALING and LIFE CHANGING song and muâ€¦',
#  'Bangladesh player Taskin Ahmed and Zimbabwe fast bowler Blessing Muzarabani have both been fined 15% of their matchâ€¦ https://t.co/KG45zCRXKF',
#  'Landslide Alertâ\x9d— \nNBRO issued landslides Level 1 watch alert for several DS divisions in Galle, Kalutara, Kegalle,â€¦ https://t.co/Yilx69dePa',
#  'Sri Lanka - India ODI series scheduled to commence from July 13th, postponed till 18th July - Secretary SLC #SLvINDâ€¦ https://t.co/pgBZFWOqKC',
#  'Photos ðŸ“· - Sri Lanka Army manage vaccination centres.\n#LKA #SriLanka #VaccineRollOutSL #VaccinationDriveSLâ€¦ https://t.co/ZpVwEwIreT',
#  'So far today 964 coronavirus cases report in Sri Lanka #LKA #SriLanka #COVID19SL #COVID19LK',
#  'A prison guard of the Mahara Prison arrested while in possession of 96 packets of heroin - Prisons Spokesman- Adaderana #LKA #SriLanka',
#  'RT @NewsCenterLk: Sri Lanka Name 25 Member Squad For India Series, Dasun Shanaka To Lead &amp; Dhananjaya is vice Captain. #Lka \nRead more: httâ€¦',
#  'RT @Dinouk_C: Problems we should discuss:\nâ€¢Fertiliser shortage\nâ€¢Rising COVID cases\nâ€¢Forced detention of protesters in quarantine centres\nâ€¢Râ€¦',
#  'RT @CassilingamG: Vaccination Centers in the #Jaffna district tomorrow.ðŸ‘‡ Those eligible under Phase 2, please do get jabbed. https://t.co/Mâ€¦',
#  '43 coronavirus related deaths confirmed for July 8th #LKA #SriLanka',
#  "Don't forget !\nCoronavirus is not over yetâ\x9d—\nFollow health guidelines ðŸ™\x8f\nðŸ”¹Wash your hands\nðŸ”¹Wear Face Mask\nðŸ”¹Maintain Sâ€¦ https://t.co/44xldWL5Vr",
#  'The Navy doctor, Mihintale PS Vice Chairman &amp; 2 gem businessmen arrested for sexual exploitation, granted bail by Câ€¦ https://t.co/QH9oZWRV7T',
#  'District-wise COVID distribution on July 8.\n* GAMPAHA 229\n* KALUTARA 180\n* COLOMBO 137\n#LKA #SriLanka #COVID19SL https://t.co/vZ7ZQj3akD',
#  'An associate of underworld figure "Chamee", arrested in Athurugiriya area along with heroin - Police #LKA #SriLanka #UnderworldSL',
#  '2021 A/L Exam will begin on October 4th and last on October 31. The relevant timetable will release to soon.\nThe Grâ€¦ https://t.co/oOjZjm22f8',
#  'Three institutes allocated for Minister Basil Rajapaksa brought back again under Prime Minister Mahinda Rajapaksa,â€¦ https://t.co/imB3uSOB7l',
#  'Samagi Jana Balawegaya SJB files FR petition before Supreme Court challenging the arrest of people under quarantineâ€¦ https://t.co/2lCuY7MI1c',
#  'Government to administer Pfizer-BionTech COVID vaccine for students going overseas for higher education and for fisâ€¦ https://t.co/7pigWm2Qlq',
#  'The highest number of COVID vaccinations administered in a single day carried out on July 8th, about 222,000 adminiâ€¦ https://t.co/Z8fUxYZuLr',
#  'Weather Alertâ\x9d—ï¸\x8f\nRainy weather and windy condition to enhance. \nHeavy rains above 100 mm in Western, Sabaragamuwa prâ€¦ https://t.co/4JvGjMAD9W',
#  'RT @Welikumbura: #SriLankan #Police arresting two old ladies at the Parliament Junction during the anti-education-militarization #protest tâ€¦',
#  'So far today total 1270 coronavirus cases report in Sri Lanka. 10,559 PCR tests. #LKA #SriLanka #COVID19SL',
#  "Tense situation reported in front of Colombo Magistrate's Court as Joseph Stalin, General Secretary of Sri Lanka Teâ€¦ https://t.co/VEjJqgpqf5",
#  'RT @LiveSahan: Police officer assaults journalist at Parliament Roundabout - Police in silenceâ€¦',
#  'RT @NewsCenterLk: Watch: "I may have to take unpleasant decisions like a father: We are in a grave situation: We were in a more hard time bâ€¦',
#  'Sri Lanka batting coach Grant Flower who arrived from England with the Sri Lankan cricketers a few days ago, testedâ€¦ https://t.co/0etiUwcuOO',
#  'So far today 842 Coronavirus cases report in Sri Lanka #LKA',
#  '40 Coronavirus related deaths for 07 July confirmed by DG of Health Services #LKA',
#  'Mohan De silva sworn in as the State Minister of Coast Conservation &amp; Low lying lands development before the President : PMD #LKA #SriLanka',
#  'Students are protesting against proposed Kotelawala University bill. Police arrested several IUSF student protestorâ€¦ https://t.co/yRrvk0VSeI',
#  'Police arrested 13 persons in Matara for holding a protest while violating quarantine regulations - Adaderana #LKA #SriLanka',
#  '#WaterCutLK - 21-hour water cut in Colombo 1, 2, 3, 7, 8, 9, 10 &amp; 11 from 9.00 AM on July 10th Saturday due to esseâ€¦ https://t.co/OKC979BThK',
#  'Finance Minister Basil Rajapaksa take oaths as a Member of Parliament before Speaker.\nCongratulations ðŸ™\x8f\n#LKAâ€¦ https://t.co/kkyIgLlHrG',
#  'MP Basil Rajapaksa sworn in before the President as the Cabinet Minister of Finance - PMD / AD #LKA #SriLanka https://t.co/w9ZlyPURvc',
#  'Prime Minister Mahinda Rajapaksa sworn in as the Minister of Economic Policies &amp; Plan Implementation before the Preâ€¦ https://t.co/XtVZmDj5Vs',
#  'Sri Lanka government to present controversial Kotelawala University Bill to Parliament today. Lecturers, students aâ€¦ https://t.co/GdZN9LpisA',
#  'A new ministry gazette as Ministry of Economic Policies &amp; Plan Implementation. Basil Rajapaksa to take oaths as a Mâ€¦ https://t.co/XQWEjnC0MK',
#  'Dasun Shanaka to be appointed as new captain of Sri Lanka cricket team : Cricket sources @NewsCenterLkâ€¦ https://t.co/W03hraG9Tb',
#  'Administering Pfizer vaccines by SL Army as 2nd dose to those who had been vaccinated with AstraZeneca will be stopâ€¦ https://t.co/nzM5euHqSn',
#  'Police Terrorist Investigation Division (TID) arrested a 24-year-old suspect in Narammala area who attended extremiâ€¦ https://t.co/WG1ftD86OA',
#  'UAE Dubai - A fire ðŸ”¥ caused by an explosion within a container on board a ship at Jebel Ali Port has been brought uâ€¦ https://t.co/VZKMb5LJGW',
#  'For the 2nd consecutive day Sri Lanka records less than 10,000 PCR tests. Only 6403 PCR tests. So far today total 1â€¦ https://t.co/FIAoxOcHgd',
#  'Those arriving in Sri Lanka from overseas after 14 days of full vaccination no longer need to undergo 14 days quaraâ€¦ https://t.co/t75zqhwAfT',
#  'Following the directives of the Ministry of Defence, Commander of the Navy has suspended the service of the naval sâ€¦ https://t.co/r0flUSw3YO',
#  'RT @CassilingamG: Vaccination Centers in the #Jaffna district tomorrow. Those eligible under Phase 2 of the program please visit your neareâ€¦',
#  '38 coronavirus related deaths confirmed for July 6th #LKA #SriLanka #COVID19SL',
#  'RT @factcrescendosl: False AlertðŸš¨\nà¶¯à·\x90à¶»à·’à¶ºà¶šà·Š à¶…à¶´à¶ºà·\x9dà¶¢à¶± à¶šà·… à·ƒà·’à¶¯à·Šà¶°à·’à¶ºà¶§ à·„à·˜à¶¯ à¶»à·\x9dà¶œ à·€à·’à·\x81à·šà·‚à¶¥ à·€à·›à¶¯à·Šâ€\x8dà¶º à·€à¶¢à·’à¶» à·ƒà·šà¶±à·\x8fà¶»à¶\xadà·Šà¶± à¶…à¶\xadà·Šà¶…à¶©à¶‚à¶œà·”à·€à¶§ à¶œà¶\xadà·Š à¶¶à·€à¶§ à·€à·Šâ€\x8dà¶ºà·\x8fà¶¢ à¶´à·”à·€à¶\xadà¶šà·Š!\nFact Cheâ€¦',
#  'So far today 678 coronavirus cases report in Sri Lanka #LKA #SriLanka',
#  'Update: Namal Karunaratne &amp; Former JVP Councilor Samantha Vidyaratna who were arrested  for holding a protest violaâ€¦ https://t.co/EIOexjSTsR',
#  '"We will not allow the government to silence Sirasa Tv" - Opposition Leader Sajith Premadasa makes special statemenâ€¦ https://t.co/QIOQiHcucs',
#  'Tense situation in Parliament as Leader of the Opposition Sajith Premadasa alleges that government is getting readyâ€¦ https://t.co/NPLWruXrdy',
#  "RT @USAmbSLM: Congratulations to ðŸ‡±ðŸ‡°'s Dananga Kaushal Agalakotuwa on his acceptance into ðŸ‡ºðŸ‡¸ @AF_Academy! Only 15 international students areâ€¦",
#  '5 persons including Duminda Nagamuwa of the Frontline Socialist Party arrested over holding a protest in Colombo 2â€¦ https://t.co/3AcZ6e5TMn',
#  "Basil Rajapaksa's name has been gazetted as the SLPP National List Member of Parliament.\n#LKA #SriLanka https://t.co/15OWXNqAhn",
#  'Sri Lankan Cricketer Angelo Mathews has reportedly informed Sri Lanka Cricket that he is considering retirement froâ€¦ https://t.co/dgNaOlZoNl',
#  'Trial at Bar appointed by the Chief Justice to hear the cases againt former Defence Secretary Hemasiri Fernando andâ€¦ https://t.co/aXr6pgvcPQ',
#  "Police arrested Samantha Vidyarathna and Namal Karunaratne for organizing farmers' protests\nhttps://t.co/KGS4rqkJyoâ€¦ https://t.co/tntGYXLQsr",
#  'Bollywood actor Dilip Kumar dies at the age of 98.\nRIP #DilipKumar ðŸ™\x8f\n#RIPDilipKumar https://t.co/bZ6DtSuJW4',
#  'Update - 25 Sri Lanka national players reportedly signed contracts for the Indian cricket tour - SLC sources- Adadeâ€¦ https://t.co/NT7NnvD2dQ',
#  'Sri Lanka to begin vaccinating school teachers ahead reopening schools. Government has taken decision to prioritizeâ€¦ https://t.co/88iTz3MtQM',
#  'RT @IndiainSL: High Commissioner met with a delegation of Tamil Progressive Alliance (TPA) MPs of #SriLanka and had a constructive discussiâ€¦',
#  '#OnThisDay in 2008, Sri Lanka won its fourth Asia Cup title, after beating India in the final by 100 runs. ðŸ\x8f†\n#LKAâ€¦ https://t.co/uA7PXnnhYD',
#  'RT @KishaniAlanki: Happy to be sharing with all of you, my latest conversation with @Sanath07 on life, cricket and the future of cricket ðŸ\x8f\x8fâ€¦',
#  'As instructed by DG Health Services, public meetings, protests etc NOT allowed to be held. Police will take stern aâ€¦ https://t.co/fZ51bT0xBs',
#  'RT @NewsCenterLk: 3 England cricketers, 4 staff members test positive for Covid-19 after Sri Lanka series. #Lka \nRead more: https://t.co/Q7â€¦',
#  'RT @kishankaru: #Pfizer 2nd ðŸ’‰for those over 55yrs who got #AstraZeneca 1st ðŸ’‰at CMC Centreâ€™s.\n\nFrom today #TeamCMC will send SMS with time/dâ€¦',
#  'RT @dinuguruge: For everyone who DIDNT get called in for the 2nd jab from CMC, but fall to the eligible age group\n\n1) Pls wait for ur turn.â€¦',
#  'RT @CassilingamG: Vaccination Centers set up in the #Jaffna district tomorrow. Those eligible under Phase 2, please do get jabbed. #SriLankâ€¦',
#  'RT @DocaAyya: Anyone over 30 years can get sinopharm (either dose) at lady Ridgeway hospital, without waiting in queue, by booking a slot oâ€¦',
#  "So far 12 cricketers signed the players' contract: Those who not sign by tomorrow morning will be expelled from Indâ€¦ https://t.co/PkSaEslyIJ",
#  'Association of Medical Specialists AMS requests government to temporarily suspend all ad-hoc salary revisions agreeâ€¦ https://t.co/a7gA4HUqHy',
#  "Total 934 coronavirus cases report in Sri Lanka on July 6th, only 5631 PCR tests done mainly due to health unions'â€¦ https://t.co/ikJbB0MNMq",
#  'Only 5631 PCR tests done on July 6th, the lowest number of PCR tests after 2 month, mainly due to health sector traâ€¦ https://t.co/9NuU50bZ1y',
#  'RT @CassilingamG: After inquiring into the allegations made by @TNAmediaoffice MP. Hon. Sritharan, I was informed by authorities that theseâ€¦',
#  'So far today 650 coronavirus cases report in Sri Lanka #LKA #SriLanka #COVID19SL',
#  '45 more coronavirus related deaths confirmed for July 5th - Govt Info #LKA #SriLanka #COVID19SL #COVID19LK',
#  'Several health sector trade unions called off their ongoing strike following discussions with the Health Minister -â€¦ https://t.co/ByL5GvXu71',
#  "Basil Rajapaksa's name has been proposed to the Election commission to fill the SLPP National List seat left vacantâ€¦ https://t.co/luBZFETfia",
#  '#SriLanka reaches 3 million milestone for Covid-19 vaccinations program. \nSo far more than 3 million Sri Lankans haâ€¦ https://t.co/ZiTDAOLFoH',
#  'RT @USAmbSLM: Increasing womenâ€™s access to finance is a key step toward encouraging economic growth. ðŸ‡ºðŸ‡¸ is providing @NDBBank with $75Mn inâ€¦',
#  'Bodies of two individuals found floating on the Bogamuwa Wewa in Weeraketiya : Newsfirst #LKA',
#  'Parliamrntarian Jayantha Ketagoda has handed over the resignation letter from the MP Post to the  Secretary Generalâ€¦ https://t.co/4qLjLSeHd7',
#  'Cabinet approval has been given to amend the Universities Act No. 16 of 1978 to include provisions required for theâ€¦ https://t.co/NcPnbYlP8Y',
#  'Minuwangoda Magistrate Court concluded the case on Brandix Cluster after AG informed the court that no lives were hâ€¦ https://t.co/3CBmSRYf06',
#  'The 26,000 doses of Pfizer vaccines received yesterday will be administered as the 2nd dose to those above 55 yearsâ€¦ https://t.co/bZjgQtRF8d',
#  'Update: Police arrested 2 more suspects including a doctor over the incident of sexual exploitation of a 15-year-olâ€¦ https://t.co/57RaFQhBU7',
#  'Uyanwaththa &amp; Uyanwaththa North Grama Niladari divisions in Matara District, Puhabugoda East GN Malabada Watta in Kâ€¦ https://t.co/dyXVydj0TY',
#  '#SriLanka today records the lowest single-day coronavirus cases after 2 months as only 869 cases detected. PCR testâ€¦ https://t.co/VAYOrDt2Ot',
#  'Minister Mahindananda Aluthgamage orders importers who have hoarded 100,000 metric tonnes of fertilisers to releaseâ€¦ https://t.co/gIIrqRUUkP',
#  'RT @CassilingamG: Vaccination centers set up in the #Jaffna district tomorrow.ðŸ‘‡ðŸ\x8f¼ https://t.co/VoAGDwiBZl',
#  'On the advice of the President, Cabinet decides to cancel the licence issued to W.M. Mendis &amp; Co. Ltd. (owned by Arâ€¦ https://t.co/mpyAA2awGX',
#  'Muslim Aid Sri Lanka donated Rs. 30 million worth of essential medical equipment including ICU ventilators, High flâ€¦ https://t.co/tNRgD5g3rp',
#  'So far today 581 coronavirus cases report in Sri Lanka #LKA #SriLanka #COVID19SL #COVID19LK',
#  '32 coronavirus related deaths confirmed for July 4th, death toll increased to 3,268 - Govt Info #LKA #SriLanka #COVID19SL #COVID19LK',
#  'Sri Lanka Cricket former performance analyst Sanath Jayasundara banned from all cricket for seven years after ICC Aâ€¦ https://t.co/yLJe4MHQO2',
#  'RT @NewsCenterLk: BREAKING: Former Maldivian Minister arrested in child sex exploitation racket in Sri Lanka. #Lka \nRead more: https://t.coâ€¦',
#  'Nimali Liyanarachchi qualified for Tokyo 2020 Olympic Games and will represent Sri Lanka for Athletes in the 800m eâ€¦ https://t.co/pOR8n0QIMI',
#  'Another judge recused himself from hearing the FR petitions filed by former Minister Rishad Bathiudeen. So far 4 juâ€¦ https://t.co/94NR0v7dpA',
#  'Students and other groups are protesting over proposed Kotelawala University Bill which they fear could pave the waâ€¦ https://t.co/M0eJYRkgGt',
#  'No-Confidence Motion NCM against Minister Udaya Gammanpila to be taken up on July 19 -20 \n- @NewsCenterLkâ€¦ https://t.co/7H4aGmLoh6',
#  'RT @AngajanR: As there are more fatalities from #Covid19 in &gt;60yrs age group, itâ€™s very important that the #elderly population gets vaccinaâ€¦',
#  'RT @CassilingamG: #Jaffna - Phase 2 of the vaccination drive will kick off in the district from Monday. Those eligible for vaccines are \n\nðŸ’‰â€¦',
#  'Another 4 suspects including a owner of a website, hotel manager and a Maldivian national arrested by the Police CIâ€¦ https://t.co/Z68prgBKW2',
#  'Sri Lanka Army established new â€˜walk inâ€™ community vaccination centres islandwide and to commence administering theâ€¦ https://t.co/7LzsVSgQLZ',
#  'Kuda Waskaduwa West Grama Niladari Division in Kalutara North Police area in the Kalutara District isolated with efâ€¦ https://t.co/EzHZYYgIo9',
#  'Schools and private candidates willing to sit for 2021 A/L Exam should send their applications via online from Julyâ€¦ https://t.co/I3Fh6zgaRY',
#  '3rd ODI b/w England &amp; Sri Lanka in Bristol called off due to bad weather conditions. England won the ODI series 2-0 #LKA #ENGvSL #SriLanka',
#  'Finance Ministry says NO decision taken to ban imports of mobile phones, TVs, refrigerators, several electronic iteâ€¦ https://t.co/P7Mh42fDyW',
#  '45 Coronavirus related deaths for 03 July confirmed by Director General of Health Services, increasing total numberâ€¦ https://t.co/Den6pVFaBA',
#  'So far today 1022 coronavirus cases report in Sri Lanka #LKA #SriLanka #COVID19SL',
#  'Inter provisional travel ban EXTENDED until July 19: Army Commander #LKA #SriLanka #COVID19SL',
#  'England won the toss and decided to bowl first in the 3rd ODI cricket match against Sri Lanka played at Bristolâ€¦ https://t.co/RFN250E9Ev',
#  '1,323 more Coronavirus patients recovered &amp; discharged from hospitals raising total number of recoveries in Sri Lanâ€¦ https://t.co/t097eQkrQ5',
#  "UNP calls for an impartial inquiry over SDIG Deshabandu Tennakoon's threatening comment to journalist Tharindu Jayaâ€¦ https://t.co/gQZ3L9rVRk",
#  'United States ðŸ‡ºðŸ‡¸ celebrates 245th Independence Day! \nHappy Independence Day ðŸ™\x8f\nHappy Fourth of July! \nWishes fromâ€¦ https://t.co/y4paCzhnM9',
#  'Rainy â˜” weather to enhance next few days.\nShowers or thundershowers in Western, Sabaragamuwa, North-Western, Southeâ€¦ https://t.co/CKuEbnV5HC',
#  'RT @USEmbSL: .@USEmbSL wishes all of you a very happy #4thofJuly! From our families to yours â€“ Happy #IndependenceDay! https://t.co/zrjeyjrâ€¦',
#  'So far 11 pregnant women have died due to COVID19 in Sri Lanka ðŸ˜¢\n.\nStay SafeðŸ¤°!\nhttps://t.co/m2wmrviLVO  #LKA #SriLanka #COVID19SL',
#  'Emirates Airline will be suspending the carriage of passengers from #SriLanka, Bangladesh &amp; Pakistan to Dubai untilâ€¦ https://t.co/TPYtzb1i4o',
#  'Naval exercise #CARAT21 held with the participation of #SriLanka Navy, United States 7th Fleet and Japanese Maritimâ€¦ https://t.co/Cy8Mif6YRc',
#  'Army Captain and three soldiers were arrested over abducting a person in Norochcholai area -@NewsCenterLkâ€¦ https://t.co/xPyjsgss5N',
#  'Another stock of  1 million doses of Sinopharm vaccines arrived to Sri Lanka - State Minister Prof. Channa Jayasumana #LKA #SriLanka',
#  '"The threat is not over yet"- Dr. Chandima Jeewandara\nLower your risk from #COVID by combining these precautions -Wâ€¦ https://t.co/A9PY2etYqN',
#  'DRIVE ðŸš—, RIDE ðŸ\x8f\x8dï¸\x8f &amp; Cross ðŸš¶SAFE!\n9 deaths reported due to road traffic accidents last 24 hours including 3 pedestriaâ€¦ https://t.co/fMdKc9Mivv',
#  'Releasing O/L exam results will be delayed due to COVID pandemic situation. https://t.co/ZoGUPqtQ7L #LKA #SriLanka #OLexam #OLresults',
#  '#JapanLandslide - 2 dead and 20 missing following a landslide occurred in Atami, Japan.\nhttps://t.co/b6b4rR5ecq #Japan #Pray',
#  'Video:#GulfOfMexicoFire ðŸ”¥ \nFlames shooting from the Gulf of Mexico after gas leak causes pipeline to catch fire.â€¦ https://t.co/Wyiy5WT0Np',
#  'Sri Lanka today records the lowest single-day coronavirus cases after 2 months as 1262 cases detected. Average PCRâ€¦ https://t.co/GqcxgqIDGe',
#  'Farmers are protesting in Sri Lanka over shortage of fertilizer.\nhttps://t.co/EaJSDuSOqZ\n#LKA #SriLanka #FarmersProtestSL #FarmersProtestLK',
#  'Police to arrest Samantha Vidyarathna and Namal Karunaratne for organizing a protest in Boralanda area -â€¦ https://t.co/aFF7QgYmUu',
#  'So far today 1010 coronavirus cases report in Sri Lanka.\n#LKA #SriLanka #COVID19SL #COVID19LK',
#  'Covid Delta variant, the most transmissible variant yet poses a major threat to unvaccinated or partially vaccinateâ€¦ https://t.co/SIjysCVZZ6',
#  '14 new cases of the Delta variant of Covid detected in Sri Lanka - Dr. Hemantha Herath, Deputy Director of Health Sâ€¦ https://t.co/bpPbNWJCoO',
#  '34 more coronavirus related deaths confirmed for July 2nd, increasing the covid death toll to 3,191 #LKA #SriLanka',
#  'Strike Alert !\nMultiple trade unions including Public Health Inspectors PHI on a token strike citing 10 demands incâ€¦ https://t.co/SBjZiQJKud',
#  "Six media rights organizations raised concern on SDIG Deshabandu Tennakoon's threatening comment to journalist Tharâ€¦ https://t.co/6kZ53Mm8JO",
#  'Today is International Day of Cooperatives!\nThe International Labour Organization is marking the #CoopsDay whileâ€¦ https://t.co/A4i37zdWCy',
#  'If you have below symptomsðŸ‘‡\nðŸ”ºBreathing difficulties \nðŸ”ºShortness of breath\nðŸ”ºFever\nðŸ”ºDry cough\nðŸ”ºTiredness\nðŸ”ºLoss of tasâ€¦ https://t.co/7nmfyRsRXw',
#  'Police arrested 24-year-old suspect for allegedly prompting the LTTE ideology through WhatsApp and Facebook groupsâ€¦ https://t.co/huDVcnXYOm',
#  'â€œOut of the 20-member India squad, 14 players have represented India across all formats or in some form and not a sâ€¦ https://t.co/uab6eULZoF',
#  'District-wise covid distribution on July 2.\nðŸ”¸GAMPAHA 267\nðŸ”¸KALUTARA 225\nðŸ”¸COLOMBO 170\nðŸ”¸RATNAPURA 124\n#LKA #SriLankaâ€¦ https://t.co/FuuixxjXu3',
#  '5 more persons arrested over sexual exploitation of the15-year old girl in Mount Lavinia area. So far 26 arrested -â€¦ https://t.co/13qBwiLBVW',
#  'Nurses strike called off after President agreed to solve demands by the Public Services United Nurses Union #LKAâ€¦ https://t.co/WSKc0gFuwV',
#  'Podujana Party SLPP suspended the party membership of the Vice-Chairman of the Mihintale Pradeshiya Saba #LKAâ€¦ https://t.co/VR6SuxeLd8',
#  'Internship opportunities for Mahiyanganaya, Kandy, Badulla, Polonnaruwa and Ampara areas.\nDetails via @rathgamaya ðŸ‘‡â€¦ https://t.co/DoRW3GVGQw',
#  'RT @CassilingamG: #Jaffna: Phase 2 of the vaccination drive will kick off in the district frm Monday. Those eligible to be vaccinated are,â€¦',
#  'RT @factcrescendosl: False AlertðŸš¨\nà¶šà¶©à·€à¶\xad à·„à·\x90à¶§à¶±à·Š à¶±à·\x90à·‚à¶±à¶½à·Š ATM à¶šà·”à¶§à·’à¶ºà·š à·ƒà·’à¶¯à·”à·€à·– à¶¸à·”à¶¯à¶½à·Š à¶¸à¶‚à¶šà·œà¶½à·Šà¶½à¶ºà¶šà·Šà¶¯?\nFact CheckedðŸ”Ž \nà¶±à·\x90à¶\xad.\nATM Robbery in Indonesia shareâ€¦',
#  'President @GotabayaR has taken steps to provide immediate solutions to five out of seven demands made by Public Serâ€¦ https://t.co/q0rJfZlqLl',
#  'RT @CPASL: Social Indicator, the survey research arm of CPA conducted an islandwide opinion poll in order to assess the socioeconomic impacâ€¦',
#  'Indian Naval Ship (INS) Sarvekshak completes 800 miles of Survey around MV Xpress Pearl, identified 54 underwater dâ€¦ https://t.co/KAY3x3uSzq',
#  'Shakib Al Hasan, Ben Cutting, James Faulkner, Temba Bavuma among top players registered for LPL-2 Draft.â€¦ https://t.co/8HBZXsch63',
#  'Update - So far today 1737 covid cases report in Sri Lanka #LKA',
#  '37 coronavirus related deaths confirmed for July 1st #LKA #SriLanka',
#  'So far today 1,102 COVID cases report in Sri Lanka #LKA #SriLanka #COVID19SL',
#  'Government is considering to reopen schools below 100 students in July month. Teachers to vaccinate before re-openiâ€¦ https://t.co/O1u80D9YNM',
#  'President Gotabaya Rajapaksa instructed the health officials to vaccinate all those over the age of 30 in the Westeâ€¦ https://t.co/IfZKi4ZSFL',
#  'UAE bans citizens from travelling to Sri Lanka, India, Pakistan and some other countries: @NewsCenterLkâ€¦ https://t.co/WBOkIKdTVq',
#  '3 buses seized in Karadiyanaru for breaching travel restrictions. 3 passengers test positive for COVID-19 : Policeâ€¦ https://t.co/Uz3MOuABKQ',
#  'U.S Government donated food aid for roughly 110,000 students. The emergency take-home rations are part of the U.S.â€¦ https://t.co/eJMjWS4Tf1',
#  'Colombo Permanent High Court Trial-at-Bar orders to release the remaining 06 defendants from the D. A. Rajapaksa meâ€¦ https://t.co/5kVFtw7nwe',
#  'Water levels in Kalu Ganga (Millakanda) and Nilwala (Panadugama) rivers rising -DMC \n#LKA #SriLanka #FloodSL',
#  'District-wise COVID distribution chart on July 1.\nðŸ”¸GAMPAHA 342\nðŸ”¸KALUTARA 247\nðŸ”¸COLOMBO 220\nðŸ”¸BATTICALOA 117\nðŸ”¸NUWARA Eâ€¦ https://t.co/UfcNZUT8AZ',
#  'A bus driver and conductor arrested on the charge of sexually harassing a 19-year old girl in Horowpathana area - Pâ€¦ https://t.co/lzqwpQqQpv',
#  'Obeysekarapura 514C GN Division in Nugegoda, Rubber Watta Village &amp; Olanda Village in Wattala, Matuwagala Watta Uppâ€¦ https://t.co/ln2kiHI49V',
#  'There is NO tsunami threat to Sri Lanka and Maldives at present due to magnitude 5.2 earthquake at South Indian Oceâ€¦ https://t.co/aKQl2rjKYj',
#  'Prevailing rainy weather condition in the South-western parts (particularly in Western and Sabaragamuwa provinces,â€¦ https://t.co/NuzjRnfyBE',
#  'Sri Lanka made 241/9 (50) against England.\nDhananjaya 91(91), Shanaka 47(67) #LKA #SriLanka #ENGvSL https://t.co/TZYnBB8vWW',
#  'The ACJU expresses its displeasure over some decisions taken on Muslim Marriage and Divorce Act by the Cabinet.\nACJâ€¦ https://t.co/gMjRIc6BhI',
#  'India ready to collaborate with Sri Lanka in its transition towards Organic Agriculture by providing capacity buildâ€¦ https://t.co/YTeKIGH3Xl',
#  '43 more coronavirus related deaths confirmed for June 30 - Government Info #LKA #SriLanka #COVID19SL #COVID19LK',
#  'Update: Vice Chairman of the Mihintale Pradeshiya Saba who arrested over the incident of sexual exploitation of a 1â€¦ https://t.co/hmMuJ74WSY',
#  'So far today 1173 coronavirus cases report in Sri Lanka #LKA',
#  "RT @USEmbSL: Don't forget to join us today at 6:00 p.m. (IST) for the live discussion with Dr. @Chris__Reddy.\nRegister for FREE via: https:â€¦",
#  'England won the toss and elected to field first in the 2nd ODI cricket match against Sri Lanka played at the Ovalâ€¦ https://t.co/LQFClGoB15',
#  'Farmers representatives are urging President Gotabaya Rajapaksa not to reverse the steps taken to use organic fertiâ€¦ https://t.co/ldch1pSiok',
#  'Major General Mohan Ratnayake released on bail over an assault to wildlife officers after produce before court :â€¦ https://t.co/L7YWxUAFHB',
#  'RT @factcrescendosl: Misleading AlertðŸš¨\nThe NASA did NOT say Ruwanweliseya Stupa is the most powerful place in the universe.\nFact CheckedðŸ”Žâ€¦',
#  'RT @sajaniveda95: Big Heart Community together with Deep Haven Counselling presents "Mental Health Management during Covid-19 ".\n\nJoin us fâ€¦',
#  'Gazette notification issued extending the retirement age of Government Doctors up to 63 years #LKA #SriLanka',
#  'â€œUnder the guise of an epidemic, government is trying to pass the Kotelawala University Bill which is destroying frâ€¦ https://t.co/8uGQJJTO8A',
#  '7 persons were seriously injured in sword attacks by a group of armed men who arrived on motorbikes in the Kondavilâ€¦ https://t.co/NlotfAOEfI',
#  'The Major General who obstructed the duties of wildlife officers of the Minneriya National Park, arrested after repâ€¦ https://t.co/an212667fu',
#  'A private passenger bus arriving in Colombo from Batticaloa with 38, including driver, conductor &amp; passengers  takeâ€¦ https://t.co/SLPfaA7MmO',
#  'Twitter Support says Profilesâ€™ Tweets may not be loading for some of users on web platform and they are currently wâ€¦ https://t.co/2aqAICLVR3',
#  "Price of bread to increaseðŸ\x8dž!\nAll Ceylon Bakers' Association says price of a bread will increase by Rs 10 from nextâ€¦ https://t.co/3uqFdM8oNX",
#  'Twitter Down ?\nWhile itâ€™s not completely down, a lot of users are reporting issues with profiles loading.â€¦ https://t.co/v8kVw0mVib',
#  'Vice-Chairman of Mihintale Pradeshiya Sabha arrested over sexual exploitation of a 15-year old girl in Mount Lavianâ€¦ https://t.co/9TxctP4Ko6',
#  'With overseas returnees cases, total 1864 covid cases report in Sri Lanka today #LKA',
#  'Sri Lankan ðŸ‡±ðŸ‡° author Kanya Dâ€™Almeida has won the 2021 Commonwealth Short Story Prize!  \nCongratulationsâ€¦ https://t.co/1yjiXrKJXg',
#  'RT @USEmbSL: ðŸ‡ºðŸ‡¸ &amp; ðŸ‡±ðŸ‡° are #WorkingTogether to combat the MV X-Press Pearl disaster. Officers from @srilanka_navy &amp; @airforcelk conducted exeâ€¦',
#  '@CassilingamG @PresRajapaksa @RajapaksaNamal Warmest wishes Geeth ðŸ™\x8f',
#  'RT @CassilingamG: Received my official letter of appointment as the Governmentâ€™s resettlement facilitator for North &amp; East, from PM @PresRaâ€¦',
#  'Army appointed a Board of Inquiry following an incident where a Senior Officer of the Army was involved in a heatedâ€¦ https://t.co/nw4ySOQJFa',
#  'Former Director of Police CID, SSP Shani Abeysekara retires from police service: @NewsCenterLk https://t.co/4viqaEXmBU #LKA #SriLanka',
#  '47 more Coronavirus related deaths have been confirmed for June 29, increasing the total death count to 3,077 #LKA #SriLanka',
#  'Death row inmates of Welikada and Mahara prisons called off their hunger strike - @NewsCenterLk \nhttps://t.co/vib3YXP6Sl #LKA #SriLanka',
#  '@Fulton89 Yes',
#  'So far today 1180 coronavirus cases report in Sri Lanka.\n#LKA #SriLanka #COVID19SL',
#  'Veteran Journalist Hudson Samarasinghe has been appointed as the Chairman of the Sri Lanka Broadcasting Corporationâ€¦ https://t.co/dD7pxX1Kvv',
#  'Central Bank printed Rs. 208.45 billion money on Monday, the most amount of money printed in a single-dayâ€¦ https://t.co/LQZ2issABE',
#  '176 Sea Turtles ðŸ\x90¢ , 4 Whales ðŸ\x90³ and 20 Dolphins ðŸ\x90¬ were killed in Sri Lanka past few weeks due to environmental polluâ€¦ https://t.co/MtT7Wa2Vzk',
#  'Strike Alertâ\x9d— \nThree nursing unions have decided to go on sick leave for two days (01st &amp; 02nd July) citing severalâ€¦ https://t.co/JadFfjQQQO',
#  "Today is Sri Lanka #Cricket Legend Sanath Jayasuriya Master Blaster's Birthday.\nHappy Birthday @Sanath07 !\n21,032 râ€¦ https://t.co/G2skLvO4Ha",
#  'Sri Lankan sprinter Yupun Abeykoon and Nilani Ratnayake (3,000m steeplechase) have qualified to compete at the Tokyâ€¦ https://t.co/R011btiOG2',
#  'Sri Lanka Army manage vaccination centres list for June 30thðŸ‘‡ https://t.co/gu4d0Og8qy',
#  'District-wise Covid cases distribution June 29\nðŸ”¶COLOMBO 348\nðŸ”¶GAMPAHA 280\nðŸ”¶KALUTARA 198\nðŸ”¶GALLE 113\n#LKA #SriLankaâ€¦ https://t.co/6NyC7hhn9C',
#  'Strike Alertâ\x9d— \nRailway engine drivers and controllers launched token strike over giving digital train tickets projeâ€¦ https://t.co/Min1TjTKZ3',
#  'RT @NewsCenterLk: T20 WC: ICC confirms move to UAE and Oman, to be held from Oct 17 to Nov 14. #ICC \nRead more: https://t.co/rToWfxQngD',
#  'England won the first ODI cricket match beating Sri Lanka by 5 wickets.\nENG 189/5 (34.5)\nSL 185 (42.3)\n#ENGvSL #LKA https://t.co/fNnEKz2Hxa',
#  'Update - So far today 1,709 coronavirus cases report in Sri Lanka #LKA #SriLanka #COVID19SL',
#  'No investigation on sexual harassments in newsrooms - Media Minister - @NewsCenterLk \nhttps://t.co/2qrVsozXQt #LKA #SriLanka #MeToo',
#  '45 more coronavirus related deaths report in Sri Lanka on June 28.\n#LKA #SriLanka #COVID19SL #COVID19LK',
#  'So far 1320 coronavirus cases report in Sri Lanka.\n#LKA #SriLanka #COVID19SL',
#  'Students and other groups in Sri Lanka have called on the government to withdraw the proposed Kotelawala Universityâ€¦ https://t.co/1HBIFv31gX',
#  'England won the toss and elected to bowl first against Sri Lanka in the first ODI cricket match.\nGood Luckâ€¦ https://t.co/HgxYgUricA',
#  'Police STF arrested a suspect with 1100 LSD Stamps containing Synthetic Drugs in Horana, Poruwadanda areaâ€¦ https://t.co/6jo2uNbrX5',
#  '36 SLPP backbenchers unanimously called Basil Rajapaksa to enter Parliament- @NewsCenterLk\nhttps://t.co/YyIFwCSCjIâ€¦ https://t.co/vtHBeTiv7h',
#  'Increase in road accidents after lifting the travel restrictions. During last 24 hour, 12 deaths have been reportedâ€¦ https://t.co/dlPvjpUuAB',
#  'Three Cricketers suspended for bio-bubble breach to arrive today in Economy Class : Cricket Sources @NewsCenterLkâ€¦ https://t.co/eEqHpknDOa',
#  'Passengers with 14 day travel history to Qatar, UAE, Saudi Arabia, Oman, Bahrain, Kuwait NOT permitted to disembarkâ€¦ https://t.co/RVYrIoJAfZ',
#  'Three people with the Delta variant of COVID-19 detected from a construction site in Colombo : DG Health Services-â€¦ https://t.co/8A8Lf1DeWu',
#  'RT @NewsCenterLk: Central Bank propose further import restrictions to manage foreign exchange reserves. #Lka\nRead more: https://t.co/CMVd3aâ€¦',
#  'RT @janitHHH: à¶”à¶¶à¶œà·š à·€à¶§à·’à¶±à·\x8f à·ƒà·„à¶ºà·\x9dà¶œà¶º à¶¶à¶½à·\x8fà¶´à·œà¶»à·œà¶\xadà·Šà¶\xadà·” à·€à¶±à·Šà¶±à·™à¶¸à·”. \n#Help #RetweeetPlease https://t.co/mldOnNj1nt',
#  "RT @Welikumbura: This is an amazing project in Araipattai Subramaniyam Vidyalaya- #Batticaloa carried out by @JayBasky's charity organizatiâ€¦",
#  'RT @IndiainSL: #OperationSagarAaraksha2\n@indiannavy ship Sarvekshak deployed for survey around #mvxpresspearl off #Colombo detected 54 objeâ€¦',
#  'Any combination of Pfizer or AstraZeneca Covid vaccine doses gives good protection against coronavirus, UK study suâ€¦ https://t.co/Hqtj0iLcZF',
#  'RT @dinuguruge: 1st doses are back!!!\n29th June\n\nSinopharm 1st dose **above 30**\n\n1. Sugathadasa Indoor Stadium\n2. Ginthupitiya MOH Officeâ€¦',
#  'Coronavirus stats in #SriLanka\nðŸ”µTotal 255,508 infected\nðŸ”µ221,249 recovered \nðŸ”µ2985 deaths\nðŸ”´31,315 active cases\nðŸ”´Dailyâ€¦ https://t.co/ZSPDo6iOpG',
#  'Update - So far today 1850 coronavirus cases report in Sri Lanka #LKA #SriLanka #COVID19SL',
#  'RT @leopocon: Leopard killed for meat in Nallathanniya. 3 arrested by DWC and later Culprits were released today on a personal bail of Rs.1â€¦',
#  'Delta variant detected in Polgasowita, says MOH; Health Ministry unaware\nhttps://t.co/XdmL4lb0G5\n#LKA #SriLanka #COVID19SL',
#  '41 more coronavirus related deaths confirmed for June 27 by DG Health Services #LKA #SriLanka',
#  "Health Ministry's Advisory Committee on Communicable Diseases grants approval for Pfizer &amp; Moderna Covid-19 vaccineâ€¦ https://t.co/exvxLl8ohL",
#  'So far today 1210 coronavirus cases report in Sri Lanka.\n#LKA #SriLanka #COVID19SL',
#  'Disembarkation in Sri Lanka NOT allowed from July 01 to visitors with a travel history of 14 days, including transiâ€¦ https://t.co/WWte7DxUog',
#  'Welcome to Sri Lanka ðŸ‡±ðŸ‡° ðŸ™\x8f\nIndian Cricket team arrived to Sri Lanka for 3 match ODI and T20 series.\nNamaste à¤¨à¤®à¤¸à¥\x8dà¤¤à¥‡ Aâ€¦ https://t.co/lVUfAQgxzc',
#  'Health Ministry says children who had been infected with  Covid-19 will be given child immunity booster vaccines afâ€¦ https://t.co/HASVepGUEX',
#  'Captain Kusal Perera apologizes to the fans for poor performances in England. \n#LKA #ENGvSL #SriLanka https://t.co/9nK66v6eeJ',
#  "RT @CassilingamG: After notifying Min.'s @RajapaksaNamal &amp; @indikaAnuruddh, swift action was taken. I thank Hon. @AngajanR, other officialsâ€¦",
#  'RT @CassilingamG: Following a request by the #Jaffna District COVID Task Force, steps were taken to immediately hand over 3 RO PLANTS whichâ€¦',
#  'Kusal, Dhanushka and Niroshan banned from playing matches until inquiry concluded over bio-bubble breaking incidentâ€¦ https://t.co/c334u3tWP8',
#  'District-wise COVID distribution last 7 days.\nðŸ”¸GAMPAHA 2,384\nðŸ”¸COLOMBO 2,125\nðŸ”¸KALUTARA 1,916\nðŸ”¸RATNAPURA 821\nðŸ”¸BATTICOâ€¦ https://t.co/xgF0ceKzOJ',
#  'Police Constable attach to Jaffna police station died following motorcycle accident. \nDrive, Rider , Cross Safely ðŸ™\x8fâ€¦ https://t.co/PNrPtmMrcN',
#  'RT @USEmbSL: Join us on July 01, 2021 at 6:00 p.m. (IST) for a live discussion w/ Dr. Chris Reddy, a senior scientist at the Department ofâ€¦',
#  'Hiru News reports that SLC has decided to bring back cricketers Kusal Mendis and Niroshan Dickwella for breaching tâ€¦ https://t.co/vb75ng3paa',
#  'Former President Maithripala Sirisena says reports claiming that he is to take oaths as a Minister, are false.- Newsfirst #LKA #SriLanka',
#  'SLC has launched an investigation over breaching the bio-bubble by two cricketers incident @NewsCenterLk #LKAâ€¦ https://t.co/oJNfYTodjy',
#  'A dog suspected of having rabies attacked at least three patients in a COVID ward at a hospital in Morawaka area -â€¦ https://t.co/OeMhCE9rVc',
#  'President @GotabayaR has submitted a proposal to the Cabinet to pay a monthly allowance of Rs. 25,000 to the livingâ€¦ https://t.co/ijOIuZ7DIr',
#  'China releases footage of its Zhurong Mars rover\n#Mars #Zhurong https://t.co/64sMOLqDwC https://t.co/5Ty2evZldh',
#  'Former Police CID Director SSP Shani Abeysekara requests security for him and his family due to threatsâ€¦ https://t.co/hcuqMeLhbA',
#  '"Decision to use organic fertilizer towards endowing a healthy future generation will not be reversed" \n@GotabayaRâ€¦ https://t.co/dsLxY53lE9',
#  'State Minister Prof. Channa Jayasumana saya one million Moderna vaccine doses through WHO COVAX facility will be prâ€¦ https://t.co/Wf7C3DSMdV',
#  "39 Coronavirus related deaths confirmed for June 26, increasing the total deaths in Sri Lanka to 2,944 - Gov't Info #LKA #SriLanka",
#  'So far today 1,245 persons tested positive for Covid19.\n#LKA #SriLanka',
#  "Four remand prisoners escape from custody while detained at the Kurunegala magistrate's court cell. One apprehendedâ€¦ https://t.co/HOZbE4KvKy",
#  'Government has decided to administer Covid-19 vaccines from next week to all those who depart Sri Lanka for foreignâ€¦ https://t.co/uRGDbjZCyt',
#  'Inquiry reveals that 425 among 632 people who received the 02nd dose of the AstraZeneca vaccine in Galle on 5th &amp; 7â€¦ https://t.co/MutWF5hv0j',
#  'Police lunched an investigation after two persons were crucified by a custodian of a Devalaya in Ampitiya, Balagollâ€¦ https://t.co/abpOPHlL3U',
#  '73% of Covid19 deaths occur in people over 60 years of age. SLMA requests Health Minister to consider allocating atâ€¦ https://t.co/BU2X8GkQd3',
#  '361 persons arrested for violating quarantine regulations during the last 24 hours: Police Spokesman\n#LKA #SriLanka #COVID19SL',
#  'After 46 days, Sri Lanka reports the lowest single-day coronavirus cases today as total 1825 new patients tested poâ€¦ https://t.co/FIr9Lxoe7n',
#  'There will be winter, there will be cold, there will be snowstorms, but then there will be spring again... \nLets Riâ€¦ https://t.co/6wbUSu06DG',
#  'England beat Sri Lanka by 89 runs to win the 3rd T20 match &amp; wins the series 3 - 0\nENG 180/6\nSL  91 (18.5)\n#LKA #SriLanka #engvssl',
#  'Sri Lanka to pay USD 1 billion loan instalment next week, the biggest installment due this year  @NewsCenterLkâ€¦ https://t.co/Z4W6Ea5x5Y',
#  "RT @CeylonAthletics: Amasha de Silva beat South Asia's favorites Dutee Chand, Archana, Daneshwari of India to win the Silver medal with Seaâ€¦",
#  'So far today 1,086 persons tested positive for Covid #LKA #SriLanka',
#  'Sri Lanka won the toss and decided to field first in 3rd T20i against England \n#LKA #SriLanka #ENGvSL https://t.co/nJdViuOdT4',
#  '43 coronavirus related deaths confirmed fr June 25, death toll increased to 2,905. \n#LKA #SriLanka #COVID19SL',
#  '2,172 more coronavirus patients recovered and discharged from hospitals today, total recoveries increased up to 216,840',
#  'Body of a male, with limbs tied, found floating in the Kelani River in Nawagamuwa. The body is suspected to be of aâ€¦ https://t.co/lJRAagIyoN',
#  'Sri Lanka Cricket Legend Rangana Herath appointed as  Bangladesh Spin Bowling Consultant: Foreign Media \nCongratulaâ€¦ https://t.co/kK84qLpP1N',
#  'Civil Rights Activist Asela Sampath, who was arrested by CID, released on bail : Newsfirst #LKA https://t.co/2zDhCFWYG5',
#  'VAT policy revision postal shipments by the EU.\nPostal Department says from July 01, all postal items excluding letâ€¦ https://t.co/0gdg0OAWCz',
#  'Asela Sampath arrested over a complaint received in connection with his claim on social media regarding covid vacciâ€¦ https://t.co/fVP6Z9fKKg',
#  'Indian Navyâ€™s Hydrographic Survey Ship ðŸš¢ INS Sarvekshak arrived at Colombo to assist in the assessment of the underâ€¦ https://t.co/AvN3zcE76n',
#  'Fire on board the MSC Messina container ship, en route to Singapore from Colombo, controlled.- Newsfirst',
#  'Fire on board the MSC Messina container ship, en route to Singapore from Colombo, controlled.- Newsfirst #LKAâ€¦ https://t.co/aYgmyztREV',
#  'MV X-Press Pearl insurers agree to honor fisheries claim of Rs. 715 Million : AGs Dept- Newsfirst\n#MVXPressPearlâ€¦ https://t.co/zuy991bFBP',
#  'US - Former Minneapolis police officer Derek Chauvin has been sentenced to 22.5 years in prison for the May 2020 muâ€¦ https://t.co/oy7U9Wk3uu',
#  '323 persons arrested for violating quarantine regulations during the last 24 hours: Police Spokesman\n#LKA #SriLanka',
#  '@kriticalvodka Wish you a happy birthday ðŸ™\x8f',
#  'Sri Lanka recorded total 1876 coronavirus cases today\n#LKA #SriLanka',
#  'Consumer Rights Activist Asela Sampath arrested by Police CID: Police #SriLanka #LKA @NewsfirstSL',
#  '"Some people were angry with the government for not fulfilling their personal demands. They are now criticizing theâ€¦ https://t.co/xljvsn9qnV',
#  "Sri Lanka President Gotabaya Rajapaksa's address to the nation full speech ðŸ‘‡\nhttps://t.co/TfBBt2lhqj  \n#LKA #SriLanka @GotabayaR",
#  'Over the next four years, government plans to construct 300,000 houses through projects implemented jointly by publâ€¦ https://t.co/VDxPhUrNqk',
#  'Since the beginning of the coronavirus pandemic, Sri Lanka government has spent over Rs. 260 Billion to provide relâ€¦ https://t.co/h648JNnwrL',
#  'President Gotabaya Rajapaksa to address the nation tonight 8.30pm - PMD #LKA #SriLanka https://t.co/CjM1mtZIKw',
#  '48 coronavirus related deaths confirmed, total death count is now 2,862 #LKA #SriLanka',
# ...
#  'RT @NewsWireLK: Vesak : Presidential pardon granted to 53 prisoners serving life sentence under special criteria https://t.co/Xu1VbVKIIf',
#  'RT @NewsWireLK: Sanjay Rajaratnam takes oaths as 48th AG : Bar Association commends President &amp; Parliamentary Council https://t.co/3XQogjsWâ€¦',
#  'The marine environment impact is severe : Sri Lanka Air Force footage of fire &amp; coastal areas at 13.00 PM todayâ€¦ https://t.co/lYmbcmOlCD',
#  '"Fire has now extended to the quarterdeck where the bridge is stationed" Navy #MVXPressPearl https://t.co/xmdW15KWEC',
#  'RT @NewsWireLK: Sri Lanka Airport to open for inbound travellers from 1st June https://t.co/5s4V2vYmmB',
#  'RT @CricWireLK: Disappointed Sanath makes request from SL Cricketers @Sanath07 ðŸ‡±ðŸ‡°ðŸ\x8f\x8f https://t.co/by4yDK6J10',
#  'Warm wishes to all those celebrating Vesak! #VesakDay https://t.co/CSua5BlyAF',
#  'RT @NewsWireLK: Ship on fire : Debris washes ashore as fire continues, crew member infected (Video) https://t.co/j412FAq5OY',
#  'RT @NewsWireLK: US clarifies terror threat alert on Sri Lanka "No change"  https://t.co/2wB2j7jwmX',
#  'Container ship on fire : Sri Lanka Air Force footage at 8.00 this morning https://t.co/mqm9q31ucP',
#  'RT @NewsWireLK: 28 more Covid deaths reported in Sri Lanka https://t.co/qlOgYgc2GE',
#  'RT @NewsWireLK: Bangladesh beat Sri Lanka for the first time in an ODI series ðŸ‡±ðŸ‡°ðŸ\x8f\x8f https://t.co/FmmmfPnuSC',
#  'RT @NewsWireLK: China Harbour bags another construction project in Sri Lanka https://t.co/ujpnXv4jeU',
#  'RT @NewsWireLK: NW BizWire : Sampath Bank PLC has been ranked as the countryâ€™s Most Loved Bank in the Brands Annual â€œMost Loved Brandsâ€\x9d lisâ€¦',
#  'RT @NewsWireLK: Wheelbarrow man arrested for not wearing face mask (Video) https://t.co/WBT0OaxfRf',
#  'RT @NewsWireLK: Isolation imposed on 30 GN divisions in six districts lifted https://t.co/NI9nW1Cyjp',
#  'RT @NewsWireLK: Fake Doctor Pass : Three arrested along with vehicles https://t.co/jYiNylEWs3',
#  "RT @NewsWireLK: Sri Lanka Navy's statement on current situation of container ship on fire https://t.co/bKIMPa11gH",
#  'RT @NewsWireLK: WATCH : "There are signs of oilspill in to the ocean from the X-Press Pearl vessel" https://t.co/h3O3FuLEJL',
#  'RT @NewsWireLK: Containers with harmful chemicals fall into sea : Special notice issued for fisherman in Western Province by Minister @kancâ€¦',
#  'RT @NewsWireLK: SJB MP Nalin Bandara &amp; wife test positive for Covid https://t.co/PFCxblhMEY',
#  'RT @NewsWireLK: WATCH : Police detect group playing cricket during lockdown using drone ðŸ\x8f\x8fðŸš” https://t.co/ATOLYOM5EZ',
#  'RT @NewsWireLK: Fire onboard vessel off the Colombo harbour intensifies : explosion reported https://t.co/6y9aJEHmjZ',
#  'RT @NewsWireLK: US issues Level 4 Travel Health Notice for Sri Lanka https://t.co/m9k4KvMHyt',
#  'RT @NewsWireLK: Details of 33 more Covid deaths released https://t.co/RPjNiySJYx',
#  'RT @NewsWireLK: WATCH : "There were too many vehicles on the road, when I came out today. So many vehicles with doctor passes. There can\'tâ€¦',
#  'RT @NewsWireLK: Cabinet suspends decision to import vehicles https://t.co/39uE9PmLDv',
#  'RT @NewsWireLK: Bangladesh Bank okays $200m currency swap with Sri Lanka https://t.co/0k8exw6VhL',
#  '@gish_dk Yes you can',
#  'RT @NewsWireLK: 06 Grama Niladhari Divisions in four districts isolated https://t.co/uhyWzVETb8',
#  'RT @NewsWireLK: The cyclonic storm â€œYAASâ€\x9d : Advisory issued for Heavy Rain &amp; Strong Winds â›ˆï¸\x8fðŸŒ©ï¸\x8fâ˜”https://t.co/HhTwAO3tYw',
#  '@sanjiva Nothing in this presser, As I know vaccination will begin soon as stocks arrive despite restrictions. Nearâ€¦ https://t.co/3hLe337oKN',
#  '@sole_passenger Not yet',
#  "RT @NewsWireLK: Travel restrictions: 11 points from today's special Covid press https://t.co/YqKCrQAFAP",
#  'Travel restrictions extended till 07th June. Restrictions will be relaxed on 25th May, 31st May, and 04th June to bâ€¦ https://t.co/M5fcYMx5CI',
#  'RT @NewsWireLK: Sri Lanka extends travel restrictions https://t.co/4CgrLEe3vX',
#  'RT @NewsWireLK: Live : Special Press Conference on Travel Restrictions https://t.co/Sk7B0zwB30',
#  'RT @NewsWireLK: Govt. to import SUVs for new Parliamentarians https://t.co/XFhIykozLB',
#  'RT @NewsWireLK: Govt. launches hotline for inquiries on essential services https://t.co/FKVgmwiBua',
#  'RT @NewsWireLK: Three, including driver arrested over death of Puttalam UC Chairman KA Baiz https://t.co/Pfg6Y2WG9H',
#  'RT @NewsWireLK: Details of 32 more Covid deaths released https://t.co/OppDMA4U6S',
#  'RT @NewsWireLK: Drive through PCR tests at private hospitals not permitted : New Guidelines issued https://t.co/FmhxDflrCT',
#  'RT @NewsWireLK: Puttalam UC chairman former MP KA Baiz has died in an accident  https://t.co/T2QFXoLfMn',
#  'Fearless Cricket : Top knock from Wanindu Hasaranga 74 (60) ðŸ‡±ðŸ‡°ðŸ\x8f\x8f https://t.co/2GVxpn7sYc',
#  'RT @NewsWireLK: Kandy District to be vaccinated using Russian Sputnik V https://t.co/RyuWhv1maE',
#  'RT @NewsWireLK: Army setting up countrywide ICCs with 20,000 beds https://t.co/xhdsyuepjx',
#  'RT @NewsWireLK: Several MPs quarantined after Sajith tests positive - Parliament https://t.co/kZwsPbiqf5',
#  'RT @NewsWireLK: Opposition Leader Sajith Premadasa &amp; his wife test positive for Covid https://t.co/S0p4a4SJVo',
#  'RT @NewsWireLK: Travel restrictions : Update from Army Commander https://t.co/t4yEa9Cs9f',
#  'SL Team for the 1st ODI ðŸ‡±ðŸ‡°ðŸ\x8f\x8f\n\n1. KJP (C/WK)\n2. Dhanuska Gunatilake \n3. Pathum Nissanka\n4. Kusal Mendis \n5. Dhananjayâ€¦ https://t.co/kjNowKviyY',
#  'RT @NewsWireLK: Bangladesh to bat first after winning the toss #SLvsBAN https://t.co/L3FkNEqs3C',
#  'In 1999, Sanath Jayasuriya took over captaincy duties to lead a young SL team at the age of 30. Today, KJP aged 30â€¦ https://t.co/SPyhOnaQ20',
#  'RT @NewsWireLK: Why short term travel restrictions have little to no effect in limiting Covid spread ? Prof. Malik Peiris explains (Video)â€¦',
#  'RT @NewsWireLK: Breaking : Sri Lanka-Bangladesh first ODI likely to go ahead after 2nd PCR clear 2 SL team members https://t.co/mTxTGZFG6h',
#  'RT @NewsWireLK: SL-Ban ODI series in doubt due to Covid scare in Sri Lanka team https://t.co/XBKgRig92x',
#  'RT @NewsWireLK: 46 more Covid deaths reported in Sri Lanka https://t.co/GeubT0ZbX0',
#  'RT @NewsWireLK: Health Ministry issues warning for Private PCR testing centers : Issues 4 new guidelines https://t.co/nWDX7mx0jf',
#  'RT @NewsWireLK: Seylan Bank staff gift fully equipped ICU to Colombo East Base Hospital https://t.co/hjemYkoZ32',
#  "RT @NewsWireLK: AG's Department removes plaque violating language rights https://t.co/LbooD8CGTT",
#  'RT @CricWireLK: Sri Lankaâ€™s full schedule for remainder of 2021 ðŸ\x8f\x8fðŸ‡±ðŸ‡° https://t.co/YQJmeMouQE',
#  'RT @NewsWireLK: SL Police launch â€˜eTrafficâ€™ app : Public urged to post traffic violation videos ðŸš”https://t.co/HSDwpuMnac',
#  'RT @NewsWireLK: 44 Covid deaths &amp; 3,547 patients reported on Friday https://t.co/bLssu5vYKv',
#  'RT @NewsWireLK: AG Dept questioned over violating national language policy https://t.co/UKem5lDgDD',
#  'President Rajapaksa said that instead of appearing unnecessarily in front of the media and intimidating the public,â€¦ https://t.co/5Yd7seYd2R',
#  'RT @NewsWireLK: Travel restrictions : 11 points on rules applicable from tonight https://t.co/gpWuOx75O9',
#  "SLPP claims @ParliamentLK failed to count 2 votes at yesterday's port city bill vote https://t.co/Wu8u9Oecb6",
#  'RT @NewsWireLK: "Don\'t hold players at gunpoint" say Sri Lankan cricketers refusing to sign contracts, hit back at officials ðŸ‡±ðŸ‡°ðŸ\x8f\x8f https://t.â€¦',
#  'RT @NewsWireLK: Nissanka Senadhipathi acquitted from illegal floating armoury case https://t.co/RvrX4t3H4Z',
#  '"It does not appear as if any of the steps implemented so far have been good enough or effective enough to achieveâ€¦ https://t.co/N1srR11PMR',
#  'RT @NewsWireLK: Fire erupts on container vessel carrying chemicals off the coast of Colombo https://t.co/woH4iOd6no',
#  'RT @NewsWireLK: 38 more covid related deaths reported in Sri Lanka. https://t.co/63edepMaIh',
#  'RT @NewsWireLK: How do you balance the relationship with China &amp; India from now on ? President replies to question raised in forum https://â€¦',
#  'RT @NewsWireLK: Port City Colombo invites local and global companies to set foot upon the gateway to South Asia https://t.co/fQWOmx1n11',
#  'RT @NewsWireLK: "Time for Total 2 weeks lockdown before healthcare system falls apart" Dr Gotabhaya Ranasinghe https://t.co/JqXix9sJ7y',
#  'RT @NewsWireLK: Colombo Port City Commission bill passed in Parliament https://t.co/Ip9sXURsl0',
#  'RT @NewsWireLK: "Stay home for 2 weeks" Minister Sudarshani urges public https://t.co/fhKe0gZK4K',
#  'RT @NewsWireLK: All ambulances allowed to travel free of charge on Expressways https://t.co/06RQ0Np33O',
#  'RT @NewsWireLK: Two arrested for defrauding Rs 11 million promising to sell iPhones &amp; iPads https://t.co/DgdweBt4lh',
#  'RT @NewsWireLK: Opposition Leader questions move to silence health officials (Video) https://t.co/ToG1hVrpss',
#  'RT @NewsWireLK: Sri Lanka Cricket office bearers elected uncontested for 2021-2023. Full list  https://t.co/I9MP2gwebK',
#  'RT @NewsWireLK: Digital vaccination ID pilot project launched https://t.co/KpsX4diKFA',
#  'RT @NewsWireLK: "Postpone the Port City vote" Elle Gunawansa thera &amp; Archbishop request Govt. https://t.co/wSwrQYfxgm',
#  'RT @NewsWireLK: Former FM @MangalaLK takes up acting, appeares in YouTube comedy https://t.co/ZbsREMbVFq',
#  'RT @NewsWireLK: China to donate another 500,000 Covid vaccine doses @ChinaEmbSL https://t.co/SQG7e08qq8',
#  'RT @NewsWireLK: Sri Lanka to close airport for arrivals for 10 days https://t.co/0rggoxMAs2',
#  'RT @NewsWireLK: SLC announces annual player contracts, 24 players issued contracts ðŸ‡±ðŸ‡°ðŸ\x8f\x8f https://t.co/a9K78Kp6pN',
#  'RT @NewsWireLK: Federal Bureau of Investigation (FBI) confirmed that Naufer Moulavi is the mastermind of the 2019 Easter Sunday attacks - Mâ€¦',
#  'RT @NewsWireLK: Japan pulls controversial asylum seeker bill after criticism over Sri Lankan woman death https://t.co/el30h1G9Rh',
#  'RT @NewsWireLK: Detained Azath Salley suffers heart attack https://t.co/Jpt2dVFWeO',
#  'RT @NewsWireLK: Australia confirms T20 series with Sri Lanka in 2021/22 home season ðŸ\x8f\x8fðŸ‡±ðŸ‡° https://t.co/9HsiroZaH5',
#  "RT @NewsWireLK: Sri Lanka's Covid death toll passes 1000 mark with 34 more deaths reported https://t.co/j2yyXI3aF5",
#  'RT @NewsWireLK: "It\'s Genocide", Sri Lankan Opp leader @sajithpremadasa condemns Israel attacks on Palestine (Video) https://t.co/ORmYZHZAVr',
#  'RT @NewsWireLK: President inspects 1200-bed Covid intermediate facility constructed by Army https://t.co/mQYEKfqtAC',
#  'RT @NewsWireLK: One-horse race for SLC election after opposing camp withdraws https://t.co/IuD11F8wyI',
#  'RT @NewsWireLK: WATCH : Heated debate in Parliament as Govt. tells Opposition Leader to watch TV news for answers for his questions on Coviâ€¦',
#  'RT @NewsWireLK: WATCH : SL Police introduce new equipment to apprehend those violating traffic laws https://t.co/pOwta0m6zK',
#  'RT @NewsWireLK: More Sputnik V vaccines to arrive next week https://t.co/KfG08iY9I0',
#  '@Kiso_Renga Yes',
#  'Slinga Lasith Malinga officially joins Twitter, pls follow him and give a welcome @ninty9sl ðŸ‡±ðŸ‡°ðŸ\x8f\x8f @MahelaJay https://t.co/4GfCmXmQyN',
#  'No more war again ðŸ‡±ðŸ‡° https://t.co/U3oeYnO2jm',
#  'RT @NewsWireLK: Speaker announces Supreme Court determination on Port City bill https://t.co/JU9IwVL1av',
#  'RT @NewsWireLK: 24th &amp; 25th May declared as Govt holidays https://t.co/UsvIat1z3n',
#  'RT @NewsWireLK: Three GN divisions in 2 districts isolated https://t.co/M9Rbr9udbg',
#  'RT @NewsWireLK: 19 Covid deaths &amp; 2,456 patients reported https://t.co/j5zNugdd1I',
#  'RT @NewsWireLK: ICC says no corruption charges over Al Jazeeraâ€™s match-fixing documentary ðŸ\x8f\x8fhttps://t.co/jzLmyCwW9v',
#  'RT @NewsWireLK: Three areas in Mullaitivu district isolated from tonight until further notice https://t.co/R8q9D3EX5T',
#  'RT @NewsWireLK: "I have always held the position that the Palestinian peopleâ€™s legitimate right to statehood must be upheld" SL PM Rajapaksâ€¦',
#  'RT @NewsWireLK: Islandwide travel restrictions to be imposed again this weekend and several days next week  https://t.co/DWfmxNaJcu',
#  "RT @NewsWireLK: Court prohibits taking Wele Suda out of prison after considering mother's petition https://t.co/zsVOpHGqVL",
#  'RT @NewsWireLK: COVID-19 patients to get treatment facilities closest to their area of residence https://t.co/h7LpBMNx4V',
#  'RT @NewsWireLK: China to rectify name board violating SL language policy https://t.co/x4vqFNBbKd',
#  'RT @NewsWireLK: Project to set up 10,000 beds in 10 days concludes with a total of 16,000 beds - @MoYS_SriLanka https://t.co/K4MxP5Nqlf',
#  'RT @NewsWireLK: Laksala Chairman &amp; SLFP party office CEO Pradeep Gunawardana dies due to Covid https://t.co/rOU5p0QpZc',
#  'RT @NewsWireLK: 70 areas in 10 Districts isolated with immediate effect https://t.co/qfoxbU7a6b',
#  'RT @NewsWireLK: Strike : Trains will not operate tomorrow (Monday) https://t.co/3KrlfF15Yp',
#  'RT @NewsWireLK: 21 more Covid deaths reported in SL https://t.co/nshuoDd3LH',
#  'RT @rajeevmenonsl: ðŸ†˜ call from the Director of DGH #Gampaha #SriLanka. With the worsening of the situation the Hospital is in dire and urgeâ€¦',
#  'RT @CricWireLK: WATCH : Murali teaches Tamil to Russel : surprises "Chilling with Russel" with hilarious banter ðŸ\x8f\x8fðŸ‡±ðŸ‡° @RusselArnold69 @farveeâ€¦',
#  'RT @NewsWireLK: Travel restrictions : 7 points on rules applicable from tomorrow https://t.co/kX8SJHYRX1',
#  'RT @NewsWireLK: Health Ministry issues latest Map of high-risk Covid19 areas in Sri Lanka https://t.co/1UlrRoIax8',
#  'RT @NewsWireLK: World Cup qualifiers : 9 crucial games coming up for Sri Lanka ðŸ‡±ðŸ‡°ðŸ\x8f\x8f https://t.co/XGpAX2yZ87',
#  '@davcliff39 home',
#  'Massive interest for Covid vaccination in Sri Lanka. Over 200,000 took the first dose in the last 3 days. A very loâ€¦ https://t.co/WerZj6uHQF',
#  "RT @NewsWireLK: Stop â€˜carrying awayâ€™ people who don't wear masks : IGP orders https://t.co/2q2E0u4xs8",
#  'RT @CricWireLK: Dickwella &amp; Dhananjaya highest paid cricketers in proposed new SLC payments scheme https://t.co/lY3TIyRiO4',
#  'RT @NotJagath: The MRI Sri Lanka is in desperate need of a High Flow Nasal Cannula Therapy Machine to assit Covid 19 patients. It costs Rs.â€¦',
#  'RT @NewsWireLK: â\xad• LIVE footage of the moment Israeli air raid bombed offices of Al Jazeera &amp; Associated Press in Gaza City https://t.co/zvHâ€¦',
#  'RT @NewsWireLK: Sri Lanka to treat asymptomatic Covid patients within their homes starting from Monday https://t.co/V6dXrHitLf',
#  'RT @NewsWireLK: Chief Selector reveals details of his meeting with Malinga over playing WT20 https://t.co/ggJoVReVy0',
#  'RT @NewsWireLK: Sri Lanka\'s first ever Hyper-casual eSport tournament "National Championship Series" to begin today https://t.co/lqko5JzyAN',
#  'RT @NewsWireLK: Sri Lanka bonds go from Asiaâ€™s worst to best after China loan - Bloomberg https://t.co/q7iegTSTaU',
#  'RT @NewsWireLK: 59 vaccination centres open today : Over 200,000 took first dose in last 3 days https://t.co/YcgESlcoiq',
#  'RT @NewsWireLK: 31 more Covid deaths &amp; 2,289 patients reported https://t.co/gXXna9g6TU',
#  'RT @NewsWireLK: Sri Lanka gets USD 80 mn additional finance from World Bank for Covid vaccines https://t.co/2FQQfurZea',
#  "RT @NewsWireLK: WATCH : Sri Lanka's Yupun remains as South Asia's fastest man setting new record https://t.co/dMFaXFqMub",
#  'RT @NewsWireLK: Get your Covid vaccine : 56 vaccination centers operating today. Full list \nhttps://t.co/GYIX7kmvFZ',
#  'RT @NewsWireLK: Pictures: Army rescues group trapped due to floods in Ruwanwella https://t.co/S29a5MLDg9',
#  'RT @NewsWireLK: 42 areas in 3 districts isolated from Monday https://t.co/uihKW01JEb',
#  ...]

# %%
for tweet in tweets:
    tweetToDB(tweet)
print("completed")
# Out:
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.

# %%
tweet = tweets[0]
sentiment_intensity =  lexicon_sentiment(tweet)
if(sentiment_intensity is not None):
    sentiment_intensity = float(sentiment_intensity)
sentiment_intensity
# Out:
# 0.050595238095238096
